# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import dabest
from pathlib import Path
import sys

sys.path.append("../")

from utils.io import read_parameters

# %%
# read parameters and key file

parameter_file = "/media/jpa/Volume/MDC/MDC_data/ec_tracking/trial/parameters_test_set.yml"
parameters = read_parameters(parameter_file)

key_file_path = parameters["key_file"]
key_file = pd.read_csv(key_file_path)

print("key file columns:", key_file.columns)
print("key file conditions:", key_file["condition"].unique())
# Out:
# key file columns: Index(['experimentID', 'filename', 'color', 'treatment_old', 'treatment',
#        'condition', 'frame_per_hour', 'date'],
#       dtype='object')
# key file conditions: ['Flow-siRNA' 'Stat-siRNA']

# %%
# parameter_file  = "../local/parameters.yml"
# parameters = read_parameters(parameter_file)   

# base_folder = parameters["base_folder"]
# tracking_data_files = parameters["tracking_data"]
# data_exclude = parameters["data_exclude"]
output_folder = Path(parameters["output_folder"])
tracking_data_path = output_folder.joinpath("speed_data")

# single_time_point_evaluation = parameters["single_time_point_evaluation"]

interval = parameters["time_lag"]

errorbar = ("ci", 95)

plt.rcParams.update({'font.size': 14})
interval = parameters["time_lag"]

subsample_n = 10  # for speed up of draft plotting
subsample_frac = 0.1  # for speed up of draft plotting

# %%
migration_speed_df = pd.DataFrame()

for index, row in key_file.iterrows():
    print("processing", row["condition"])
    #tracking_data_file = tracking_data_path + row["filename"]
    tracking_data_file = output_folder.joinpath(
        "speed_data",
        "migration_speed_df_%s_%s_%s.csv" % (row["treatment"], row["color"], row["experimentID"])
    )
    tracking_data = pd.read_csv(str(tracking_data_file))

    tracking_data['color'] = row['color']
    tracking_data['treatment'] = row['treatment']
    tracking_data['experimentID'] = row['experimentID']

    if migration_speed_df.empty:
        migration_speed_df = tracking_data
    else:
        migration_speed_df = pd.concat([migration_speed_df, tracking_data], ignore_index=True)

#migration_speed_df = migration_speed_df[migration_speed_df["time_lag"] == interval]
migration_speed_df
# Out:
# processing Flow-siRNA
# processing Flow-siRNA
# processing Stat-siRNA
# processing Flow-siRNA
#          TRACK_ID  POSITION_X  POSITION_Y  POSITION_T  FRAME  ORIGIN_X  \
# 0            2036      1518.0      2452.0         0.0      0       0.0
# 1            2036      1517.0      2450.0       360.0      1      -1.0
# 2            2036      1517.0      2450.0       720.0      2      -1.0
# 3            2036      1516.0      2450.0      1080.0      3      -2.0
# 4            2036      1519.0      2448.0      1440.0      4       1.0
# ...           ...         ...         ...         ...    ...       ...
# 3612736      7960      1965.0      2604.0     77760.0    216       2.0
# 3612737      7960      1964.0      2602.0     78120.0    217       1.0
# 3612738      7960      1964.0      2608.0     78480.0    218       1.0
# 3612739      7960      1965.0      2608.0     78840.0    219       2.0
# 3612740      7960      1966.0      2608.0     79200.0    220       3.0
#
#          ORIGIN_Y  step_size  step_size_x  step_size_y  vel_mu_per_h  \
# 0             0.0      0.000          0.0          0.0           NaN
# 1            -2.0      0.000          0.0          0.0           NaN
# 2            -2.0      0.000          0.0          0.0           NaN
# 3            -2.0      0.000          0.0          0.0           NaN
# 4            -4.0      4.123          1.0         -4.0        10.308
# ...           ...        ...          ...          ...           ...
# 3612736      -2.0      4.123          1.0         -4.0        10.308
# 3612737      -4.0      8.062         -1.0         -8.0        20.156
# 3612738       2.0      4.123          1.0          4.0        10.308
# 3612739       2.0      6.000          0.0          6.0        15.000
# 3612740       2.0      4.123          1.0          4.0        10.308
#
#          vel_x_mu_per_h  vel_y_mu_per_h      phi  \
# 0                   NaN             NaN  180.000
# 1                   NaN             NaN  180.000
# 2                   NaN             NaN  180.000
# 3                   NaN             NaN  180.000
# 4                   2.5           -10.0 -104.036
# ...                 ...             ...      ...
# 3612736             2.5           -10.0 -104.036
# 3612737            -2.5           -20.0  -82.875
# 3612738             2.5            10.0  104.036
# 3612739             0.0            15.0   90.000
# 3612740             2.5            10.0  104.036
#
#                                                   filename   condition  \
# 0        tracking_data_siCtrl+highVEGF-Flow_black_D2_re...  Flow-siRNA
# 1        tracking_data_siCtrl+highVEGF-Flow_black_D2_re...  Flow-siRNA
# 2        tracking_data_siCtrl+highVEGF-Flow_black_D2_re...  Flow-siRNA
# 3        tracking_data_siCtrl+highVEGF-Flow_black_D2_re...  Flow-siRNA
# 4        tracking_data_siCtrl+highVEGF-Flow_black_D2_re...  Flow-siRNA
# ...                                                    ...         ...
# 3612736  tracking_data_siGENOMEsiKank1+lowVEGF-Flow_bla...  Flow-siRNA
# 3612737  tracking_data_siGENOMEsiKank1+lowVEGF-Flow_bla...  Flow-siRNA
# 3612738  tracking_data_siGENOMEsiKank1+lowVEGF-Flow_bla...  Flow-siRNA
# 3612739  tracking_data_siGENOMEsiKank1+lowVEGF-Flow_bla...  Flow-siRNA
# 3612740  tracking_data_siGENOMEsiKank1+lowVEGF-Flow_bla...  Flow-siRNA
#
#          time_in_h  color                     treatment experimentID
# 0              0.0  black          siCtrl+highVEGF-Flow      D2_rep1
# 1              0.1  black          siCtrl+highVEGF-Flow      D2_rep1
# 2              0.2  black          siCtrl+highVEGF-Flow      D2_rep1
# 3              0.3  black          siCtrl+highVEGF-Flow      D2_rep1
# 4              0.4  black          siCtrl+highVEGF-Flow      D2_rep1
# ...            ...    ...                           ...          ...
# 3612736       21.6  black  siGENOMEsiKank1+lowVEGF-Flow      G1_rep1
# 3612737       21.7  black  siGENOMEsiKank1+lowVEGF-Flow      G1_rep1
# 3612738       21.8  black  siGENOMEsiKank1+lowVEGF-Flow      G1_rep1
# 3612739       21.9  black  siGENOMEsiKank1+lowVEGF-Flow      G1_rep1
# 3612740       22.0  black  siGENOMEsiKank1+lowVEGF-Flow      G1_rep1
#
# [3612741 rows x 20 columns]

# %%
full_hours = np.arange(0, migration_speed_df["FRAME"].max(), interval)
print(full_hours)
migration_speed_df = migration_speed_df[migration_speed_df["FRAME"].isin(full_hours)]
migration_speed_df
# Out:
# [  0   4   8  12  16  20  24  28  32  36  40  44  48  52  56  60  64  68
#   72  76  80  84  88  92  96 100 104 108 112 116 120 124 128 132 136 140
#  144 148 152 156 160 164 168 172 176 180 184 188 192 196 200 204 208 212
#  216 220]
#          TRACK_ID  POSITION_X  POSITION_Y  POSITION_T  FRAME  ORIGIN_X  \
# 0            2036      1518.0      2452.0         0.0      0       0.0
# 4            2036      1519.0      2448.0      1440.0      4       1.0
# 8            2036      1519.0      2444.0      2880.0      8       1.0
# 12           2036      1516.0      2446.0      4320.0     12      -2.0
# 16           2036      1503.0      2448.0      5760.0     16     -15.0
# ...           ...         ...         ...         ...    ...       ...
# 3612724      7934      1937.0      2338.0     77760.0    216       2.0
# 3612728      7934      1938.0      2342.0     79200.0    220       3.0
# 3612732      7960      1964.0      2608.0     76320.0    212       1.0
# 3612736      7960      1965.0      2604.0     77760.0    216       2.0
# 3612740      7960      1966.0      2608.0     79200.0    220       3.0
#
#          ORIGIN_Y  step_size  step_size_x  step_size_y  vel_mu_per_h  \
# 0             0.0      0.000          0.0          0.0           NaN
# 4            -4.0      4.123          1.0         -4.0        10.308
# 8            -8.0      4.000          0.0         -4.0        10.000
# 12           -6.0      3.606         -3.0          2.0         9.014
# 16           -4.0     13.153        -13.0          2.0        32.882
# ...           ...        ...          ...          ...           ...
# 3612724     -10.0      8.246          2.0         -8.0        20.616
# 3612728      -6.0      4.123          1.0          4.0        10.308
# 3612732       2.0      0.000          0.0          0.0           NaN
# 3612736      -2.0      4.123          1.0         -4.0        10.308
# 3612740       2.0      4.123          1.0          4.0        10.308
#
#          vel_x_mu_per_h  vel_y_mu_per_h      phi  \
# 0                   NaN             NaN  180.000
# 4                   2.5           -10.0 -104.036
# 8                   0.0           -10.0  -90.000
# 12                 -7.5             5.0   33.690
# 16                -32.5             5.0    8.746
# ...                 ...             ...      ...
# 3612724             5.0           -20.0 -104.036
# 3612728             2.5            10.0  104.036
# 3612732             NaN             NaN  180.000
# 3612736             2.5           -10.0 -104.036
# 3612740             2.5            10.0  104.036
#
#                                                   filename   condition  \
# 0        tracking_data_siCtrl+highVEGF-Flow_black_D2_re...  Flow-siRNA
# 4        tracking_data_siCtrl+highVEGF-Flow_black_D2_re...  Flow-siRNA
# 8        tracking_data_siCtrl+highVEGF-Flow_black_D2_re...  Flow-siRNA
# 12       tracking_data_siCtrl+highVEGF-Flow_black_D2_re...  Flow-siRNA
# 16       tracking_data_siCtrl+highVEGF-Flow_black_D2_re...  Flow-siRNA
# ...                                                    ...         ...
# 3612724  tracking_data_siGENOMEsiKank1+lowVEGF-Flow_bla...  Flow-siRNA
# 3612728  tracking_data_siGENOMEsiKank1+lowVEGF-Flow_bla...  Flow-siRNA
# 3612732  tracking_data_siGENOMEsiKank1+lowVEGF-Flow_bla...  Flow-siRNA
# 3612736  tracking_data_siGENOMEsiKank1+lowVEGF-Flow_bla...  Flow-siRNA
# 3612740  tracking_data_siGENOMEsiKank1+lowVEGF-Flow_bla...  Flow-siRNA
#
#          time_in_h  color                     treatment experimentID
# 0              0.0  black          siCtrl+highVEGF-Flow      D2_rep1
# 4              0.4  black          siCtrl+highVEGF-Flow      D2_rep1
# 8              0.8  black          siCtrl+highVEGF-Flow      D2_rep1
# 12             1.2  black          siCtrl+highVEGF-Flow      D2_rep1
# 16             1.6  black          siCtrl+highVEGF-Flow      D2_rep1
# ...            ...    ...                           ...          ...
# 3612724       21.6  black  siGENOMEsiKank1+lowVEGF-Flow      G1_rep1
# 3612728       22.0  black  siGENOMEsiKank1+lowVEGF-Flow      G1_rep1
# 3612732       21.2  black  siGENOMEsiKank1+lowVEGF-Flow      G1_rep1
# 3612736       21.6  black  siGENOMEsiKank1+lowVEGF-Flow      G1_rep1
# 3612740       22.0  black  siGENOMEsiKank1+lowVEGF-Flow      G1_rep1
#
# [912473 rows x 20 columns]

# %%
plot_migration_speeds = migration_speed_df.dropna()

# filter observation time

obs_start = parameters["observation_time"][0]
obs_end = parameters["observation_time"][1]

plot_migration_speeds = plot_migration_speeds[plot_migration_speeds["FRAME"] >= obs_start]
plot_migration_speeds = plot_migration_speeds[plot_migration_speeds["FRAME"] <= obs_end]

plot_mean_migration_speeds = plot_migration_speeds.groupby(["experimentID", "condition", "color"])

plot_mean_migration_speeds = plot_mean_migration_speeds.mean(numeric_only=True).add_suffix('').reset_index()
plot_mean_migration_speeds["condition_color"] = plot_mean_migration_speeds["condition"] + "_" + \
                                                plot_mean_migration_speeds["color"]

display(plot_mean_migration_speeds)
# Out:
#   experimentID   condition  color     TRACK_ID   POSITION_X   POSITION_Y  \
# 0      D1_rep1  Stat-siRNA  black  2024.563757  1388.199184  1280.585492
# 1      D2_rep1  Flow-siRNA  black  2069.410856  1343.947937  1314.449557
# 2      E7_rep2  Flow-siRNA  black  2268.019904  1346.967353  1284.607147
# 3      G1_rep1  Flow-siRNA  black  2242.754231  1364.205760  1298.444187
#
#     POSITION_T      FRAME  ORIGIN_X  ORIGIN_Y  step_size  step_size_x  \
# 0  5140.028538  14.277857 -0.041497  0.802203  11.304832    -0.214327
# 1  5109.102724  14.191952 -2.473194  1.088404  10.575755    -1.944054
# 2  5050.957343  14.030437 -3.419426  1.071541   8.383966    -2.050878
# 3  5068.542653  14.079285 -2.376834  1.879812   7.939877    -1.386397
#
#    step_size_y  vel_mu_per_h  vel_x_mu_per_h  vel_y_mu_per_h        phi  \
# 0    -0.005903     28.238218       -0.534355       -0.017632   6.859091
# 1     0.197829     26.426396       -4.857341        0.494009   6.981318
# 2     0.166875     20.950259       -5.123302        0.415707   7.619157
# 3     0.489172     19.839484       -3.462623        1.222295  10.483180
#
#    time_in_h   condition_color
# 0   1.427786  Stat-siRNA_black
# 1   1.419195  Flow-siRNA_black
# 2   1.403044  Flow-siRNA_black
# 3   1.407929  Flow-siRNA_black

# %%
fig, ax = plt.subplots(1, figsize=(9, 6))

condition_palette = dict()

for cond in plot_mean_migration_speeds["condition_color"].unique():
    if "green" in cond:
        condition_palette[cond] = "limegreen"
    elif "red" in cond:
        condition_palette[cond] = "violet"
    #else:
    #    condition_palette[cond] = "red"

#sns.color_palette("husl", len(plot_mean_migration_speeds["condition_color"].unique()))

properties_dabest = dabest.load(data=plot_mean_migration_speeds, x="condition_color", y="vel_x_mu_per_h",
                                idx=('Stat-siRNA_black', 'Flow-siRNA_black'))

#properties_dabest = dabest.load(data = plot_other_df, x="CONDITION", y="clustering",
#
#                           idx=(( 'mosaic_siCTRL_siCTRL',  'mosaic_siCTRL_siSMAD4',  'mosaic_siCTRL_siAlk1')))

print(properties_dabest.mean_diff)
display(properties_dabest.mean_diff.results)

#properties_dabest = dabest.load(data = summary_data_CTR, x="time_interval", y="labelled_arterial_ECs",
#                          idx=('P8_P9', 'P5_P6', 'P5_P7', 'P5_P8', 'P5_P9'))

# Produce a Cumming estimation plot.
#test = properties_dabest.mean_diff.plot(swarm_ylim=(0, 10), contrast_ylim=(-3, 2));
#test = properties_dabest.mean_diff.plot(swarm_ylim=swarm_ylim, custom_palette = time_condition_palette) #, contrast_ylim=(-4, 2));
test = properties_dabest.mean_diff.plot(ax=ax, custom_palette=condition_palette)
test.savefig(output_folder + "mean_velocity_parallel_to_flow.pdf")
test.savefig(output_folder + "mean_velocity_parallel_to_flow.png")
# Out:
# /home/jpa/micromamba/envs/trackme/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jpa/micromamba/envs/trackme/lib/python3.13/site-packages/numpy/_core/_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/jpa/micromamba/envs/trackme/lib/python3.13/site-packages/dabest/_effsize_objects.py:323: UserWarning: The lower limit of the BCa interval cannot be computed. It is set to the effect size itself. All bootstrap values were likely all the same.
#   warnings.warn(err_temp.substitute(lim_type="lower"), stacklevel=0)
# /home/jpa/micromamba/envs/trackme/lib/python3.13/site-packages/dabest/_effsize_objects.py:327: UserWarning: The upper limit of the BCa interval cannot be computed. It is set to the effect size itself. All bootstrap values were likely all the same.
#   warnings.warn(err_temp.substitute(lim_type="upper"), stacklevel=0)
# /home/jpa/micromamba/envs/trackme/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jpa/micromamba/envs/trackme/lib/python3.13/site-packages/numpy/_core/_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/jpa/micromamba/envs/trackme/lib/python3.13/site-packages/dabest/_effsize_objects.py:523: UserWarning: The lower limit of the BCa interval of baseline curve cannot be computed. It is set to the effect size itself. All bootstrap values were likely all the same.
#   warnings.warn(err_temp.substitute(lim_type="lower"), stacklevel=0)
# /home/jpa/micromamba/envs/trackme/lib/python3.13/site-packages/dabest/_effsize_objects.py:527: UserWarning: The upper limit of the BCa interval of baseline curve cannot be computed. It is set to the effect size itself. All bootstrap values were likely all the same.
#   warnings.warn(err_temp.substitute(lim_type="upper"), stacklevel=0)
# /home/jpa/micromamba/envs/trackme/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:4318: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/jpa/micromamba/envs/trackme/lib/python3.13/site-packages/numpy/_core/_methods.py:219: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/micromamba/envs/trackme/lib/python3.13/site-packages/dabest/_effsize_objects.py:1058, in EffectSizeDataFrame.__repr__(self)
#    1057 try:
# -> 1058     return self.__for_print
#    1059 except AttributeError:
#
# AttributeError: 'EffectSizeDataFrame' object has no attribute '_EffectSizeDataFrame__for_print'
#
# During handling of the above exception, another exception occurred:
#
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[23], line 21
#      15 properties_dabest = dabest.load(data = plot_mean_migration_speeds, x="condition_color", y="vel_x_mu_per_h", idx=('Stat-siRNA_black', 'Flow-siRNA_black'))
#      17 #properties_dabest = dabest.load(data = plot_other_df, x="CONDITION", y="clustering",
#      18 #
#      19 #                           idx=(( 'mosaic_siCTRL_siCTRL',  'mosaic_siCTRL_siSMAD4',  'mosaic_siCTRL_siAlk1')))
# ---> 21 print(properties_dabest.mean_diff)
#      22 display(properties_dabest.mean_diff.results)
#      24 #properties_dabest = dabest.load(data = summary_data_CTR, x="time_interval", y="labelled_arterial_ECs",
#      25 #                          idx=('P8_P9', 'P5_P6', 'P5_P7', 'P5_P8', 'P5_P9'))
#      26
#      27 # Produce a Cumming estimation plot.
#      28 #test = properties_dabest.mean_diff.plot(swarm_ylim=(0, 10), contrast_ylim=(-3, 2));
#      29 #test = properties_dabest.mean_diff.plot(swarm_ylim=swarm_ylim, custom_palette = time_condition_palette) #, contrast_ylim=(-4, 2));
#
# File ~/micromamba/envs/trackme/lib/python3.13/site-packages/dabest/_effsize_objects.py:1060, in EffectSizeDataFrame.__repr__(self)
#    1058     return self.__for_print
#    1059 except AttributeError:
# -> 1060     self.__pre_calc()
#    1061     return self.__for_print
#
# File ~/micromamba/envs/trackme/lib/python3.13/site-packages/dabest/_effsize_objects.py:912, in EffectSizeDataFrame.__pre_calc(self)
#     910     control = grouped_data[cname]
#     911 test = grouped_data[tname]
# --> 912 result = TwoGroupsEffectSize(
#     913     control,
#     914     test,
#     915     self.__effect_size,
#     916     self.__is_proportional,
#     917     self.__is_paired,
#     918     self.__ci,
#     919     self.__resamples,
#     920     self.__permutation_count,
#     921     self.__random_seed,
#     922     self.__ps_adjust
#     923 )
#     924 r_dict = result.to_dict()
#     925 r_dict["control"] = cname
#
# File ~/micromamba/envs/trackme/lib/python3.13/site-packages/dabest/_effsize_objects.py:183, in TwoGroupsEffectSize.__init__(self, control, test, effect_size, proportional, is_paired, ci, resamples, permutation_count, random_seed, ps_adjust)
#     179 self.__pct_high = sorted_bootstraps[pct_idx_high]
#     181 self._get_bootstrap_baseline_ec()
# --> 183 self._perform_statistical_test()
#
# File ~/micromamba/envs/trackme/lib/python3.13/site-packages/dabest/_effsize_objects.py:436, in TwoGroupsEffectSize._perform_statistical_test(self)
#     431 except ValueError as e:
#     432     warnings.warn("Mann-Whitney test could not be performed. This might be due "
#     433       "to identical rank values in both control and test groups. "
#     434       "Details: {}".format(e))
# --> 436 standardized_es = es.cohens_d(self.__control, self.__test, is_paired=None)
#
# ZeroDivisionError: division by zero

# %%
fig, ax = plt.subplots(1, figsize=(9, 6))

condition_palette = dict()

for cond in plot_mean_migration_speeds["condition_color"].unique():
    if "green" in cond:
        condition_palette[cond] = "limegreen"
    elif "red" in cond:
        condition_palette[cond] = "violet"
    #else:
    #    condition_palette[cond] = "red"

#sns.color_palette("husl", len(plot_mean_migration_speeds["condition_color"].unique()))

properties_dabest = dabest.load(data=plot_mean_migration_speeds, x="condition_color", y="vel_mu_per_h",
                                idx=(('mosaic_siScr_siScr_green', 'mosaic_siScr_siScr_red'),
                                     ('mosaic_siScr_siCdc42_green', 'mosaic_siScr_siCdc42_red'),
                                     ('mosaic_siScr_siRac1_green', 'mosaic_siScr_siRac1_red')))

#properties_dabest = dabest.load(data = plot_other_df, x="CONDITION", y="clustering",
#
#                           idx=(( 'mosaic_siCTRL_siCTRL',  'mosaic_siCTRL_siSMAD4',  'mosaic_siCTRL_siAlk1')))

print(properties_dabest.mean_diff)
display(properties_dabest.mean_diff.results)

#properties_dabest = dabest.load(data = summary_data_CTR, x="time_interval", y="labelled_arterial_ECs",
#                          idx=('P8_P9', 'P5_P6', 'P5_P7', 'P5_P8', 'P5_P9'))

# Produce a Cumming estimation plot.
#test = properties_dabest.mean_diff.plot(swarm_ylim=(0, 10), contrast_ylim=(-3, 2));
#test = properties_dabest.mean_diff.plot(swarm_ylim=swarm_ylim, custom_palette = time_condition_palette) #, contrast_ylim=(-4, 2));
test = properties_dabest.mean_diff.plot(ax=ax, custom_palette=condition_palette)
test.savefig(output_folder + "mean_velocity.pdf")
test.savefig(output_folder + "mean_velocity.png")
